# %% [markdown]
# # **자료형과 반복문 Lab 연습**

# %%
# 변수 c에 "red" "blue" "yellow" 세 개의 문자열을 저장하세요
c = ["red", "blue", "yellow"]

print(c)

# c의 자료형을 출력하세요
print(type(c))
# Out:
# ['red', 'blue', 'yellow']
# <class 'list'>

# %%
a = [1, 2, 3, 4]
print(a[1])
print(a[-2])

# %%
fruits = ["apple", 2, "orange", 4, "grape", 3, "banana", 1]

# 변수 fruits의 두 번째 요소를 출력합니다
print(fruits[1])

# %% [markdown]
# 문제 **1**. 변수 fruits의 마지막 요소를 출력하세요

# %%
alphabet = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"]
print(alphabet[1:5])
print(alphabet[1:-5])
print(alphabet[:5])

# %%
chaos = ["cat", "apple", 2, "orange", 4, "grape", 3, "banana", 1]
print(chaos)

# %% [markdown]
# 문제 **2**. chaos 리스트에서 ["apple", 2, "orange", 4] 리스트를 꺼내 변수 fruits에 저장하세요

# %%
c = ["dog", "blue", "yellow"]
# 변수 c의 첫 번째 요소를 "red"로 바꾸세요.
c[0] = "red"
print(c)

# %%
dic ={"Korea": "Seoul", "France": "Paris"}
print(dic["Korea"])

# %%
x =  5

# while을 사용하여 변수 x가 0이 아닐 동안 루프하도록 만들어주세요
while x != 0:
    # 반복문 속에서 변수 x에서 1을 빼고, 출력합니다
    x -= 1
    print(x)

# %%
animals = ["tiger", "dog", "elephant"]
for animal in animals:
    print(animal)

# %%
storages = [1, 2, 3, 4]

# %% [markdown]
# 문제 **3**. for 문으로 변수 storages의 요소를 출력하세요

# %% [markdown]
# 문제 **4**. 변수 n의 값이 3일 때 처리를 종료하세요

# %%
for i in storages:
  print(i)
  # 여기에 if문을 작성하세요.

# %%
storages = [1, 2, 3, 4, 5, 6]

for n in storages:
    # 변수 n이 2의 배수일 때만 처리를 생략하세요
    if n % 2 == 0:
        continue
    print(n)

# %%
animals = ["tiger", "dog", "elephant"]

# enumerate() 함수를 이용하여 출력하세요
for index, animal in enumerate(animals):
    print("index:" + str(index), animal)

# %%
fruits = [["strawberry", "red"],
          ["peach", "pink"],
          ["banana", "yellow"]]

# for 문을 사용하여 출력하세요
for fruit, color in fruits:
    print(fruit + " is " + color)

# %%
fruits = {"strawberry": "red", "peach": "pink", "banana": "yellow"}
for fruit, color in fruits.items():
    print(fruit + " is " + color)
