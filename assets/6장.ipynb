# %%
#  출처:파이썬으로 배우는 딥러닝 교과서
vege = "potato"
n = [4, 5, 2, 7, 6]

# 변수 vege의 오브젝트의 길이를 출력하세요
print(len(vege))

# 변수 n의 오브젝트의 길이를 출력하세요
print(len(n))
# Out:
# 6
# 5

# %%
# append의 복습
alphabet = ["a","b","c","d","e"]
alphabet.append("f")
print(alphabet)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
# sorted 입니다
number = [1,5,3,4,2]
print(sorted(number)) # sorted : 원본 리스트에 영향 없음.
print(number)
# Out:
# [1, 2, 3, 4, 5]
# [1, 5, 3, 4, 2]

# %%
# sorted 입니다
number = [1,5,3,4,2]
number.sort() # sort : 원본 리스트에 영향 있음.
print(number)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 메서드의 예입니다
city = "Sookmyung"
print(city.upper())
print(city.count("o"))
# Out:
# SOOKMYUNG
# 2

# %%
print("{}에서 태어나 {}에서 유년기를 보냈습니다".format("서울", "광명시"))
# Out:
# 서울에서 태어나 광명시에서 유년기를 보냈습니다

# %%
이름 = "눈송이"
학번 = "123456"

# "banana는 yellow입니다"라고 출력하세요
print("저의 이름은 {}이고, 학번은 {}입니다".format(이름, 학번))
# Out:
# 저의 이름은 눈송이이고, 학번은 123456입니다

# %%
alphabet = ["a", "b", "c", "d", "d"]
print(alphabet.index("a"))
print(alphabet.count("d"))
# Out:
# 0
# 2

# %%
n = [3, 6, 8, 6, 3, 2, 4, 6]

# "2"의 인덱스 번호를 출력하세요
print()

# 변수 n에 "6"이 몇 개 있는지 출력하세요
print()

# %%
# reverse()의 예
list = ["가", "나", "다", "라", "마"]
list.reverse()
print(list)
# Out:
# ['마', '라', '다', '나', '가']

# %%
n = [53, 26, 37, 69, 24, 2]

# n을 정렬하여 오름차순으로 출력하세요
n.sort()
print(n)

# n의 순서를 반대로 하여, 내림차순으로 출력하세요
n.reverse()
print(n)
# Out:
# [2, 24, 26, 37, 53, 69]
# [69, 53, 37, 26, 24, 2]

# %%
def sing():
    print("노래합니다!")
    
sing()
# Out:
# 노래합니다!

# %%
def introduce(n):
    print(n + "입니다")

introduce("홍길동")
# Out:
# 홍길동입니다

# %%
# 인수 n을 세제곱한 값을 출력하는 함수 cube_cal을 만드세요
def cube_cal(n):
    print(n ** 3) 

# 함수를 호출합니다
cube_cal(4)
# Out:
# 64

# %%
# 함수 introduce를 만드세요
def introduce(n, age):
    print("이름은 " + n + "이고, "+ str (age) + "살입니다.")

# 함수를 호출하세요
introduce("홍길동", 18)
# Out:
# 이름은 홍길동이고, 18살입니다.

# %%
# 초기값을 설정하세요
def introduce(age, n):
    print(n + "입니다." + str(age) + "살입니다.")

# 함수를 호출합니다

# %%
# 초기값을 설정하세요
def introduce(age, n = "홍길동"):
    print(n + "입니다. " + str(age) + "살입니다.")

# 함수를 호출합니다
# Out:
# 홍길동입니다. 18살입니다.

# %%
# bmi을 계산하는 함수를 만들고, bmi를 반환 값으로 만드세요
def bmi(height, weight):
    return weight / height**2 

print(bmi(1.65, 65))
# Out:
# 23.875114784205696

# %%
# MyProduct 클래스를 정의합니다
class MyProduct:
    # 생성자를 수정하세요
    def __init__(self, name, price, stock):
        # 인수를 멤버에 저장하세요
        self.name = name
        self.price = price
        self.stock = stock
        self.sales = 0

# MyProduct를 호출하여 객체 product_1을 만듭니다
product_1 = MyProduct("cake", 500, 20) 

# product_1의 stock을 출력하세요
print(product_1.stock)
# Out:
# 20

# %%
# MyProduct 클래스를 정의합니다
class MyProduct:
    def __init__(self, name, price, stock):
        self.name = name
        self.price = price
        self.stock = stock
        self.sales = 0
    # 요약 메서드
    # 문자열과 "자신의 방법"과 "자신의 구성원"을 연결하여 출력하세요
    def summary(self):
        message = "called summary()." + \
        "\n name: " + self.get_name() + \
        "\n price: " + str(self.price) + \
        "\n stock: " + str(self.stock) + \
        "\n sales: " + str(self.sales)
        print(message)
    # name을 반환하는 get_name()를 작성하세요
    def get_name(self):
        return self.name

    # 인수만큼 price를 뺴주는 discount()를 작성하세요
    def discount(self, n):
        self.price -= n

product_2 = MyProduct("phone", 30000, 100)
# 5,000 만큼 discount하세요
product_2.discount(5000)
# product_2의 summary를 출력하세요
product_2.summary()
# Out:
# called summary().
#  name: phone
#  price: 25000
#  stock: 100
#  sales: 0

# %%
pai = 3.141592
print("원주율은 %f" % pai)
print("원주율은 %.2f" % pai)
# Out:
# 원주율은 3.141592
# 원주율은 3.14

# %%
def bmi(height, weight):
    return weight / height**2

# "bmi는 **입니다"라고 출력시켜주세요
print("bmi는 %.4f입니다" % bmi(1.65, 65))
# Out:
# bmi는 23.8751입니다
